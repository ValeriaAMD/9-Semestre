# %%
# 8.	Crear un nuevo paquete de Python en el cual tendremos 3 módulos, 
# modulo 1: calcular el área de un circulo (declarar pi como 3.1416),
# modulo2: calcular el área de un hexágono regular, 
# modulo 3: calcular la circunferencia de un circulo. 
# Crear un script de menú para acceder a dichas funciones

# %%
# 9.	Leer el archivo de datos Spotify (30)
# a.	Obtener el máximo y mínimo de la columna streams -
# b.	Obtener un nuevo dataframe con los stremas promedios de cada año -
# c.	A la columna de artist_count cambiar los valores de 1 por la palabra UNO -
# d.	Crear 3 graficas(pastel, histograma y dispersión) a consideración del alumno con la 
#   información del dataframe original (datos Spotify)

# %%
import pandas as pd
import matplotlib as plot   
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\caroc\Untitled Folder\ExamenU1\datos_spotify.csv',encoding='latin1')

# %%
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
maximo = df.groupby(['artist(s)_name'])['streams'].max()

# %%
maximo
# Out:
# artist(s)_name
# (G)I-DLE                                          170709584
# 21 Savage, Gunna                                   60680939
# 24kgoldn, Iann Dior                              1699402402
# 50 Cent                                          1202722675
# A$AP Rocky, Metro Boomin, Roisee                   94186466
#                                                     ...
# j-hope                                            155795783
# j-hope, J. Cole                                   116599790
# sped up 8282                                      103762518
# sped up nightcore, ARIZONATEARS, Lil Uzi Vert     207033255
# teto                                              139193812
# Name: streams, Length: 645, dtype: int64

# %%
minimo = df.groupby(['artist(s)_name'])['streams'].min()

# %%
minimo
# Out:
# artist(s)_name
# (G)I-DLE                                           96273746
# 21 Savage, Gunna                                   60680939
# 24kgoldn, Iann Dior                              1699402402
# 50 Cent                                          1202722675
# A$AP Rocky, Metro Boomin, Roisee                   94186466
#                                                     ...
# j-hope                                            155795783
# j-hope, J. Cole                                   116599790
# sped up 8282                                      103762518
# sped up nightcore, ARIZONATEARS, Lil Uzi Vert     207033255
# teto                                              139193812
# Name: streams, Length: 645, dtype: int64

# %%
maximo = maximo.reset_index()

# %%
maximo
# Out:
#                                     artist(s)_name     streams
# 0                                         (G)I-DLE   170709584
# 1                                 21 Savage, Gunna    60680939
# 2                              24kgoldn, Iann Dior  1699402402
# 3                                          50 Cent  1202722675
# 4                 A$AP Rocky, Metro Boomin, Roisee    94186466
# ..                                             ...         ...
# 640                                         j-hope   155795783
# 641                                j-hope, J. Cole   116599790
# 642                                   sped up 8282   103762518
# 643  sped up nightcore, ARIZONATEARS, Lil Uzi Vert   207033255
# 644                                           teto   139193812
#
# [645 rows x 2 columns]

# %%
minimo = minimo.reset_index()

# %%
minimo
# Out:
#                                     artist(s)_name     streams
# 0                                         (G)I-DLE    96273746
# 1                                 21 Savage, Gunna    60680939
# 2                              24kgoldn, Iann Dior  1699402402
# 3                                          50 Cent  1202722675
# 4                 A$AP Rocky, Metro Boomin, Roisee    94186466
# ..                                             ...         ...
# 640                                         j-hope   155795783
# 641                                j-hope, J. Cole   116599790
# 642                                   sped up 8282   103762518
# 643  sped up nightcore, ARIZONATEARS, Lil Uzi Vert   207033255
# 644                                           teto   139193812
#
# [645 rows x 2 columns]

# %%
prom = df.groupby(['released_year'])['streams'].mean()

# %%
prom = prom.reset_index()

# %%
prom
# Out:
#     released_year       streams
# 0            1930  9.059852e+07
# 1            1942  3.955914e+08
# 2            1946  3.897720e+08
# 3            1950  4.732483e+08
# 4            1952  3.955914e+08
# 5            1957  4.599810e+08
# 6            1958  4.368543e+08
# 7            1959  2.867089e+08
# 8            1963  4.370878e+08
# 9            1968  1.145728e+09
# 10           1970  2.600173e+08
# 11           1971  4.604928e+08
# 12           1973  8.385868e+08
# 13           1975  2.103053e+09
# 14           1979  4.039395e+08
# 15           1982  1.751377e+08
# 16           1983  1.593271e+09
# 17           1984  8.679063e+08
# 18           1985  1.115405e+09
# 19           1986  5.668379e+08
# 20           1987  1.553498e+09
# 21           1991  1.029420e+09
# 22           1992  1.271293e+09
# 23           1994  1.449779e+09
# 24           1995  9.685020e+08
# 25           1996  1.069331e+08
# 26           1997  1.037625e+08
# 27           1998  1.284943e+09
# ...

# %%
prom.to_csv(r'C:\Users\caroc\Untitled Folder\ExamenU1\stremsprom.csv')

# %%
df['artist_count']
# Out:
# 0      2
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 948    1
# 949    1
# 950    2
# 951    3
# 952    1
# Name: artist_count, Length: 953, dtype: int64

# %%
df['artist_count'] = df['artist_count'].replace(1,'UNO')

# %%
df['artist_count']
# Out:
# 0        2
# 1      UNO
# 2      UNO
# 3      UNO
# 4      UNO
#       ...
# 948    UNO
# 949    UNO
# 950      2
# 951      3
# 952    UNO
# Name: artist_count, Length: 953, dtype: object

# %%
plotear = df[df.released_year==2023]

# %%
plotear.streams.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
plotear.plot.scatter(x="released_month", y="released_day", alpha=0.2)
# Out:
# <Axes: xlabel='released_month', ylabel='released_day'>

# %%
subs_prom = df.groupby("released_year")["streams"].mean()
subs_prom.plot.barh()
# Out:
# <Axes: ylabel='released_year'>

# %%
plotear.artist_count.value_counts().plot.pie()
# Out:
# <Axes: ylabel='artist_count'>
