# %%
##Crear un script donde leamos nuestro archivo de datos2 y generar un DataFrame a partir de este.

# %%
import pandas as pd
import matplotlib as plt   #las librerias se tienen que importar cada que haga un nuevo codigo
import numpy as np

# %%
##a. A la columna youtuber pasar los datos a mayúsculas upper()

# %%
## b. Obtener el máximo de “uploads” para cada “category”
## c. Obtener el mínimo de “uploads” para cada “category”
## d. Obtener un data frame nuevo, a partir de los pasos anteriores.
## e. Cambiar todos los valores ‘United states’ por la palabra “U.S.” en la columna ‘Country’
## f. Imprimir la información de nuestro data frame

# %%
df = pd.read_csv(r'C:\Users\caroc\OneDrive\Documentos\datos_youtube\datos2.csv',encoding='latin1') #la r se pone para dejar la

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
df['Youtuber'] = df['Youtuber'].str.upper()

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-SERIES    245000000  2.280000e+11
# 1       2              YOUTUBE MOVIES    170000000  0.000000e+00
# 2       3                     MRBEAST    166000000  2.836884e+10
# 3       4  COCOMELON - NURSERY RHYMES    162000000  1.640000e+11
# 4       5                   SET INDIA    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               NATAN POR AÏ¿     12300000  9.029610e+09
# 991   992    FREE FIRE INDIA OFFICIAL     12300000  1.674410e+09
# 992   993                       PANDA     12300000  2.214684e+09
# 993   994                 ROBTOPGAMES     12300000  3.741235e+08
# 994   995                MAKE JOKE OF     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
mayu = df['Youtuber']

# %%
mayu
# Out:
# 0                        T-SERIES
# 1                  YOUTUBE MOVIES
# 2                         MRBEAST
# 3      COCOMELON - NURSERY RHYMES
# 4                       SET INDIA
#                   ...
# 990                 NATAN POR AÏ¿
# 991      FREE FIRE INDIA OFFICIAL
# 992                         PANDA
# 993                   ROBTOPGAMES
# 994                  MAKE JOKE OF
# Name: Youtuber, Length: 995, dtype: object

# %%
mayu = mayu.reset_index()

# %%
mayu
# Out:
#      index                    Youtuber
# 0        0                    T-SERIES
# 1        1              YOUTUBE MOVIES
# 2        2                     MRBEAST
# 3        3  COCOMELON - NURSERY RHYMES
# 4        4                   SET INDIA
# ..     ...                         ...
# 990    990               NATAN POR AÏ¿
# 991    991    FREE FIRE INDIA OFFICIAL
# 992    992                       PANDA
# 993    993                 ROBTOPGAMES
# 994    994                MAKE JOKE OF
#
# [995 rows x 2 columns]

# %%
maxi = df.groupby(['category'])['uploads'].max()

# %%
maxi
# Out:
# category
# Autos & Vehicles           2942
# Comedy                     8976
# Education                 52144
# Entertainment            151136
# Film & Animation          39113
# Gaming                   156215
# Howto & Style              6734
# Movies                     5436
# Music                     65286
# News & Politics          296272
# Nonprofits & Activism    200933
# People & Blogs           301308
# Pets & Animals            16047
# Science & Technology      10162
# Shows                    116536
# Sports                    70127
# Trailers                   9168
# Travel & Events             766
# Name: uploads, dtype: int64

# %%
minim = df.groupby(['category'])['uploads'].min()

# %%
minim
# Out:
# category
# Autos & Vehicles          855
# Comedy                      0
# Education                   0
# Entertainment               0
# Film & Animation            0
# Gaming                      0
# Howto & Style               0
# Movies                   1670
# Music                       0
# News & Politics             6
# Nonprofits & Activism    4891
# People & Blogs              0
# Pets & Animals              8
# Science & Technology        0
# Shows                       0
# Sports                    389
# Trailers                 4510
# Travel & Events           766
# Name: uploads, dtype: int64

# %%
maxi = maxi.reset_index()

# %%
maxi
# Out:
#                  category  uploads
# 0        Autos & Vehicles     2942
# 1                  Comedy     8976
# 2               Education    52144
# 3           Entertainment   151136
# 4        Film & Animation    39113
# 5                  Gaming   156215
# 6           Howto & Style     6734
# 7                  Movies     5436
# 8                   Music    65286
# 9         News & Politics   296272
# 10  Nonprofits & Activism   200933
# 11         People & Blogs   301308
# 12         Pets & Animals    16047
# 13   Science & Technology    10162
# 14                  Shows   116536
# 15                 Sports    70127
# 16               Trailers     9168
# 17        Travel & Events      766

# %%
minim = minim.reset_index()

# %%
minim
# Out:
#                  category  uploads
# 0        Autos & Vehicles      855
# 1                  Comedy        0
# 2               Education        0
# 3           Entertainment        0
# 4        Film & Animation        0
# 5                  Gaming        0
# 6           Howto & Style        0
# 7                  Movies     1670
# 8                   Music        0
# 9         News & Politics        6
# 10  Nonprofits & Activism     4891
# 11         People & Blogs        0
# 12         Pets & Animals        8
# 13   Science & Technology        0
# 14                  Shows        0
# 15                 Sports      389
# 16               Trailers     4510
# 17        Travel & Events      766

# %%
maxi = maxi.rename(columns={'uploads':'uploads_max'})
minim = minim.rename(columns={'uploads':'uploads_min'})

# %%
nuevo= maxi.merge(minim, on = ['category'])

# %%
nuevo
# Out:
#                  category  uploads_max  uploads_min
# 0        Autos & Vehicles         2942          855
# 1                  Comedy         8976            0
# 2               Education        52144            0
# 3           Entertainment       151136            0
# 4        Film & Animation        39113            0
# 5                  Gaming       156215            0
# 6           Howto & Style         6734            0
# 7                  Movies         5436         1670
# 8                   Music        65286            0
# 9         News & Politics       296272            6
# 10  Nonprofits & Activism       200933         4891
# 11         People & Blogs       301308            0
# 12         Pets & Animals        16047            8
# 13   Science & Technology        10162            0
# 14                  Shows       116536            0
# 15                 Sports        70127          389
# 16               Trailers         9168         4510
# ...

# %%
df['Country']
# Out:
# 0               India
# 1       United States
# 2       United States
# 3       United States
# 4               India
#             ...
# 990            Brazil
# 991             India
# 992    United Kingdom
# 993            Sweden
# 994             India
# Name: Country, Length: 995, dtype: object

# %%
df['Country'] = df['Country'].replace('United States','U.S.')

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-SERIES    245000000  2.280000e+11
# 1       2              YOUTUBE MOVIES    170000000  0.000000e+00
# 2       3                     MRBEAST    166000000  2.836884e+10
# 3       4  COCOMELON - NURSERY RHYMES    162000000  1.640000e+11
# 4       5                   SET INDIA    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               NATAN POR AÏ¿     12300000  9.029610e+09
# 991   992    FREE FIRE INDIA OFFICIAL     12300000  1.674410e+09
# 992   993                       PANDA     12300000  2.214684e+09
# 993   994                 ROBTOPGAMES     12300000  3.741235e+08
# 994   995                MAKE JOKE OF     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...
