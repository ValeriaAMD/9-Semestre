# %%
import pandas as pd
import matplotlib as plot

# %%
df = pd.read_csv(r'C:\Users\caroc\OneDrive\Documentos\datos_youtube\datos1.csv') #la r se pone para dejar la

# %%
df
# Out:
#       ID_estacion  Nombre_estacion                fecha  prec  temt   dirv  \
# 0              27  INIFAP SALTILLO  2018-09-01 00:00:00   0.0  18.8  154.4
# 1              27  INIFAP SALTILLO  2018-09-01 00:15:00   0.0  17.9   96.2
# 2              27  INIFAP SALTILLO  2018-09-01 00:30:00   NaN  17.4    NaN
# 3              27  INIFAP SALTILLO  2018-09-01 00:45:00   0.0  17.2  141.2
# 4              27  INIFAP SALTILLO  2018-09-01 01:00:00   0.0  16.5  130.0
# ...           ...              ...                  ...   ...   ...    ...
# 2875           27  INIFAP SALTILLO  2018-09-30 22:45:00   0.0  14.2  102.5
# 2876           27  INIFAP SALTILLO  2018-09-30 23:00:00   0.0  14.4   43.0
# 2877           27  INIFAP SALTILLO  2018-09-30 23:15:00   0.0  15.0  108.8
# 2878           27  INIFAP SALTILLO  2018-09-30 23:30:00   0.0  15.3  177.6
# 2879           27  INIFAP SALTILLO  2018-09-30 23:45:00   0.0  15.2  187.7
#
#       velv  radg  humr  humh  eto
# ...

# %%
df['fecha']=pd.to_datetime(df['fecha'])

# %%
df['anio']=df['fecha'].dt.year
df['mes']=df['fecha'].dt.month
df['dia']=df['fecha'].dt.day

# %%
df['hour']=df['fecha'].dt.hour

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
plotear = df[df.dia==1] #plotear es parte de un df

# %%
plotear.temt. plot.hist() #el plot.hist() es el formato de la grafica o bien, la forma en que se vera
# Out:
# <Axes: ylabel='Frequency'>

# %%
plotear.plot.scatter(x="dirv", y="velv", alpha=0.2)
# Out:
# <Axes: xlabel='dirv', ylabel='velv'>

# %%
temt_prom = plotear.groupby("hour")["temt"].mean()
temt_prom.head(25).plot.barh()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 temt_prom = plotear.groupby("hour")["temt"].mean()
#       2 temt_prom.head(25).plot.barh()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# ...

# %%
plotear.velv.value_counts().plot.pie()
# Out:
# <Axes: ylabel='velv'>

# %%
#grafica de pastel con la avervacion de coutry 
#histograma con la columna de uploads
#grafica de barras agrupando el chanel type y el promedio de los suscriptores

# %%
#histograma con la columna uploads
df = pd.read_csv(r'C:\Users\caroc\OneDrive\Documentos\datos_youtube\datos2.csv',encoding='latin1')

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
plotear = df[df.uploads==50]

# %%
df.uploads. plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
#grafica de pastel con la avervacion de coutry 
df.Abbreviation.value_counts().plot.pie()
# Out:
# <Axes: ylabel='Abbreviation'>

# %%
#grafica de barras agrupando el chanel type y el promedio de los suscriptores 
subs_prom = df.groupby("channel_type")["subscribers"].mean()
subs_prom.plot.barh()
# Out:
# <Axes: ylabel='channel_type'>
