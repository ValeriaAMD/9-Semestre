# %%
import pandas as pd
import matplotlib as plot   
import numpy as np

# %%
df1= pd.read_csv(r'C:\Users\caroc\Untitled Folder\Apuntes\Procesamiento a\recetas\Analisis.csv', encoding='latin-1')
df2= pd.read_csv(r'C:\Users\caroc\Untitled Folder\Apuntes\Procesamiento a\recetas\Consultorio.csv', encoding='latin-1')
df3= pd.read_csv(r'C:\Users\caroc\Untitled Folder\Apuntes\Procesamiento a\recetas\Doctores.csv', encoding='latin-1')
df4= pd.read_csv(r'C:\Users\caroc\Untitled Folder\Apuntes\Procesamiento a\recetas\Paciente.csv', encoding='latin-1')
df5= pd.read_csv(r'C:\Users\caroc\Untitled Folder\Apuntes\Procesamiento a\recetas\H_Recetas.csv', encoding='latin-1')

# %%
df5.head()
# Out:
#    id_doctor  id_analisis  id_paciente  id_consultorio        medicamento  \
# 0       1012            1            1               1        Paracetamol
# 1       1027            1           16               6  Hidroclorotiazida
# 2       1042            1           31              12          Valsartan
# 3       1057            1           46               4        Diclofenaco
# 4       1072            1           61               9      Atorvastatina
#
#    farmacia  total_pagar
# 0         1          500
# 1         1          500
# 2         1          500
# 3         1          500
# 4         1          500

# %%
plotea = df5

# %%
plotea.medicamento.value_counts().plot.pie()
# Out:
# <Axes: ylabel='medicamento'>

# %%
df5.head()
# Out:
#    id_doctor  id_analisis  id_paciente  id_consultorio        medicamento  \
# 0       1012            1            1               1        Paracetamol
# 1       1027            1           16               6  Hidroclorotiazida
# 2       1042            1           31              12          Valsartan
# 3       1057            1           46               4        Diclofenaco
# 4       1072            1           61               9      Atorvastatina
#
#    farmacia  total_pagar
# 0         1          500
# 1         1          500
# 2         1          500
# 3         1          500
# 4         1          500

# %%
subs_prom = df5.groupby("id_paciente")["id_analisis"].mean()
subs_prom.plot.barh()
# Out:
# <Axes: ylabel='id_paciente'>

# %%
df1.head()
# Out:
#               Tipo        fecha   horario
# 0  calculos renales  20/01/2022  13:00:00
# 1        globulinas  25/02/2023  12:00:00
# 2       complemento  13/06/2023  16:00:00
# 3             semen  12/12/2020  17:00:00
# 4         anoscopia  04/04/2023  11:00:00

# %%
plote = df1

# %%
plote.plot.scatter(x="horario", y="fecha", alpha=0.2)
# Out:
# <Axes: xlabel='horario', ylabel='fecha'>
