# %%
import pandas as pd
import pyodbc

# %%
df1= pd.read_csv(r'D:\0Descargas\cd_Alumnos_Discapacidad_CONALEP_Junio2023.csv', encoding='latin-1')

# %%
df1
# Out:
#      Cve_Entidad               Entidad  Cve Plantel            Plantel  \
# 0             11            Guanajuato          163           Acámbaro
# 1             12              Guerrero          111         Acapulco I
# 2             12              Guerrero          206        Acapulco II
# 3             14               Jalisco          182  Acatlán de Juárez
# 4             22  Querétaro de Arteaga          328        Aeronáutico
# ..           ...                   ...          ...                ...
# 308           29              Tlaxcala          101          Zacualpan
# 309           16   Michoacán de Ocampo           88             Zamora
# 310           14               Jalisco          258            Zapopan
# 311           12              Guerrero           27        Zihuatanejo
# 312           16   Michoacán de Ocampo          240          Zitácuaro
#
#          Periodo   Alumnos_discapacidad
# 0    2022-2023-02                     0
# ...

# %%
minimo = df1.groupby(['Cve_Entidad'])['Alumnos_discapacidad'].min()

# %%
minimo = minimo.reset_index()

# %%
grupoMin = df1.groupby(['Plantel','Alumnos_discapacidad'])['Cve_Entidad'].min()

# %%
grupoMin = grupoMin.reset_index()

# %%
grupoMin
# Out:
#                Plantel  Alumnos_discapacidad  Cve_Entidad
# 0           Acapulco I                     0           12
# 1          Acapulco II                     0           12
# 2    Acatlán de Juárez                     0           14
# 3             Acámbaro                     0           11
# 4          Aeronáutico                     0           22
# ..                 ...                   ...          ...
# 308          Zacualpan                     0           29
# 309             Zamora                     0           16
# 310            Zapopan                     0           14
# 311        Zihuatanejo                     2           12
# 312          Zitácuaro                     0           16
#
# [313 rows x 3 columns]

# %%
minimo
# Out:
#     Cve_Entidad  Alumnos_discapacidad
# 0             1                     0
# 1             2                     0
# 2             3                     0
# 3             4                     0
# 4             5                     0
# 5             6                     0
# 6             7                     0
# 7             8                     0
# 8             9                     0
# 9            10                     0
# 10           11                     0
# 11           12                     0
# 12           13                     0
# 13           14                     0
# 14           15                     0
# 15           16                     0
# 16           17                     2
# 17           18                     0
# 18           19                     0
# 19           20                     0
# 20           21                     0
# 21           22                     0
# 22           23                     0
# 23           24                     0
# ...
