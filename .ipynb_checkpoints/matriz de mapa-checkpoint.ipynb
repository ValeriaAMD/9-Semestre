# %%
for x in range(32.75, 14.74):
    for y in range(-117.34, -85.78):
        i = 0.045

# %%
for_uno = [32.75, 14.74]
i = 0.045

matriz = []
for valor in for_uno:
    resultado = valor - i
    fila.append(resultado)
matriz.append(fila)

for fila in matriz:
    print(fila)
# Out:
# [16.21375, 16.21375, 16.21375, 32.705, 14.695]

# %%
for_uno = [-117.34, -85.78]
i = 0.045

matriz = []
for valor in for_uno:
    resultado = valor - i
    fila.append(resultado)
matriz.append(fila)

for fila in matriz:
    print(fila)
# Out:
# [16.21375, 16.21375, 16.21375, 32.705, 14.695, -117.385, -85.825]

# %%
# Definir los valores
i = 0.045

# Inicializar la matriz
matriz = []

# Llenar la matriz con los valores dados
for valor in range(int(32.75 / i), int(14.74 / i), -1):
    fila = [valor * i + 14.74] #round para evitar tantos decimales
    matriz.append(fila)

# Imprimir la matriz
for fila in matriz:
    print(fila)
# Out:
# [47.455]
# [47.410000000000004]
# [47.365]
# [47.32]
# [47.275]
# [47.230000000000004]
# [47.185]
# [47.14]
# [47.095]
# [47.050000000000004]
# [47.005]
# [46.96]
# [46.915]
# [46.87]
# [46.825]
# [46.78]
# [46.735]
# [46.69]
# [46.644999999999996]
# [46.6]
# [46.555]
# [46.51]
# [46.464999999999996]
# [46.42]
# [46.375]
# [46.33]
# [46.285]
# [46.24]
# [46.195]
# [46.15]
# [46.105]
# [46.06]
# [46.015]
# [45.97]
# [45.925]
# [45.88]
# [45.835]
# [45.79]
# [45.745]
# [45.699999999999996]
# [45.655]
# [45.61]
# [45.565]
# [45.519999999999996]
# [45.475]
# [45.43]
# [45.385]
# [45.339999999999996]
# [45.295]
# [45.25]
# [45.205]
# [45.16]
# [45.115]
# [45.07]
# [45.025]
# [44.98]
# [44.935]
# [44.89]
# [44.845]
# [44.8]
# [44.755]
# [44.71]
# [44.665]
# [44.62]
# [44.574999999999996]
# [44.53]
# [44.485]
# [44.44]
# [44.394999999999996]
# [44.35]
# [44.305]
# [44.26]
# [44.214999999999996]
# [44.17]
# [44.125]
# [44.08]
# [44.035]
# [43.99]
# [43.945]
# [43.9]
# [43.855]
# [43.81]
# ...

# %%
# Definir los valores
i = 0.045

# Inicializar la matriz
matriz = []

# Llenar la matriz con los valores dados
for valor in range(int(-117.34 / i), int(-85.78 / i)):
    fila = [valor * i + 14.74] * 3
    matriz.append(fila)

# Imprimir la matriz
for fila in matriz:
    print(fila)
# Out:
# [-102.575, -102.575, -102.575]
# [-102.53, -102.53, -102.53]
# [-102.485, -102.485, -102.485]
# [-102.44, -102.44, -102.44]
# [-102.395, -102.395, -102.395]
# [-102.35, -102.35, -102.35]
# [-102.305, -102.305, -102.305]
# [-102.26, -102.26, -102.26]
# [-102.215, -102.215, -102.215]
# [-102.17, -102.17, -102.17]
# [-102.125, -102.125, -102.125]
# [-102.08, -102.08, -102.08]
# [-102.035, -102.035, -102.035]
# [-101.99, -101.99, -101.99]
# [-101.94500000000001, -101.94500000000001, -101.94500000000001]
# [-101.9, -101.9, -101.9]
# [-101.855, -101.855, -101.855]
# [-101.81, -101.81, -101.81]
# [-101.765, -101.765, -101.765]
# [-101.72, -101.72, -101.72]
# [-101.675, -101.675, -101.675]
# [-101.63, -101.63, -101.63]
# [-101.585, -101.585, -101.585]
# [-101.54, -101.54, -101.54]
# [-101.495, -101.495, -101.495]
# [-101.45, -101.45, -101.45]
# [-101.405, -101.405, -101.405]
# [-101.36, -101.36, -101.36]
# [-101.315, -101.315, -101.315]
# [-101.27, -101.27, -101.27]
# ...
