# %%
#librerias

# %%
#
#unique da los valores unicos (que no se repiten o diferentes)
#nnuniunique  nos dice cuantos valores hay 
#max para sacar el maximo de una columna
#min el minimo de la coumna
#mean se saca el promedio de la columna
#

# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\caroc\OneDrive\Documentos\datos_youtube\datos1.csv') #la r se pone para dejar la 
                                                                                   #ruta tal cual y no cambiar las diagonales

# %%
df
# Out:
#       ID_estacion  Nombre_estacion                fecha  prec  temt   dirv  \
# 0              27  INIFAP SALTILLO  2018-09-01 00:00:00   0.0  18.8  154.4
# 1              27  INIFAP SALTILLO  2018-09-01 00:15:00   0.0  17.9   96.2
# 2              27  INIFAP SALTILLO  2018-09-01 00:30:00   NaN  17.4    NaN
# 3              27  INIFAP SALTILLO  2018-09-01 00:45:00   0.0  17.2  141.2
# 4              27  INIFAP SALTILLO  2018-09-01 01:00:00   0.0  16.5  130.0
# ...           ...              ...                  ...   ...   ...    ...
# 2875           27  INIFAP SALTILLO  2018-09-30 22:45:00   0.0  14.2  102.5
# 2876           27  INIFAP SALTILLO  2018-09-30 23:00:00   0.0  14.4   43.0
# 2877           27  INIFAP SALTILLO  2018-09-30 23:15:00   0.0  15.0  108.8
# 2878           27  INIFAP SALTILLO  2018-09-30 23:30:00   0.0  15.3  177.6
# 2879           27  INIFAP SALTILLO  2018-09-30 23:45:00   0.0  15.2  187.7
#
#       velv  radg  humr  humh  eto
# ...

# %%
df['prec'].unique()
# Out:
# array([ 0. ,  nan,  0.2,  3.4,  1. ,  1.2, 13.8,  4.4,  0.4,  0.6,  0.8,
#         4.6,  9. ,  2. , 10.2,  2.2,  2.8,  9.4,  7.6,  1.6,  4.2,  1.4,
#        10.8,  8.2, 14.2,  6.4,  6. ,  3. ,  7. ,  5.8,  3.2,  1.8,  2.4])

# %%
df['prec'].nunique()
# Out:
# 32

# %%
df['temt'].max()
# Out:
# 28.3

# %%
df['temt'].min()
# Out:
# 12.5

# %%
df['temt'].mean()
# Out:
# 18.550243055555555

# %%
df2 = df [df.prec > 0]

# %%
df2
# Out:
#       ID_estacion  Nombre_estacion                fecha  prec  temt   dirv  \
# 80             27  INIFAP SALTILLO  2018-09-01 20:00:00   0.2  17.9   83.8
# 153            27  INIFAP SALTILLO  2018-09-02 14:15:00   0.2  23.2  301.7
# 154            27  INIFAP SALTILLO  2018-09-02 14:30:00   3.4  21.5  116.8
# 316            27  INIFAP SALTILLO  2018-09-04 07:00:00   0.2  16.1  147.7
# 351            27  INIFAP SALTILLO  2018-09-04 15:45:00   1.0  21.0  311.0
# ...           ...              ...                  ...   ...   ...    ...
# 2764           27  INIFAP SALTILLO  2018-09-29 19:00:00   0.4  16.4  207.0
# 2765           27  INIFAP SALTILLO  2018-09-29 19:15:00   0.6  16.1  111.8
# 2766           27  INIFAP SALTILLO  2018-09-29 19:30:00   0.8  16.0   23.5
# 2767           27  INIFAP SALTILLO  2018-09-29 19:45:00   0.2  15.9  330.0
# 2768           27  INIFAP SALTILLO  2018-09-29 20:00:00   0.2  15.9   39.4
#
#       velv   radg  humr  humh  eto
# ...

# %%
df2.to_csv(r'C:\Users\caroc\OneDrive\Documentos\datos_youtube\datos3.csv')

# %%
df2.to_csv(r'C:\Users\caroc\OneDrive\Documentos\datos_youtube\datos4.csv', index=False)

# %%
df2 = df2.reset_index()

# %%
df2
# Out:
#      index  ID_estacion  Nombre_estacion                fecha  prec  temt  \
# 0       80           27  INIFAP SALTILLO  2018-09-01 20:00:00   0.2  17.9
# 1      153           27  INIFAP SALTILLO  2018-09-02 14:15:00   0.2  23.2
# 2      154           27  INIFAP SALTILLO  2018-09-02 14:30:00   3.4  21.5
# 3      316           27  INIFAP SALTILLO  2018-09-04 07:00:00   0.2  16.1
# 4      351           27  INIFAP SALTILLO  2018-09-04 15:45:00   1.0  21.0
# ..     ...          ...              ...                  ...   ...   ...
# 203   2764           27  INIFAP SALTILLO  2018-09-29 19:00:00   0.4  16.4
# 204   2765           27  INIFAP SALTILLO  2018-09-29 19:15:00   0.6  16.1
# 205   2766           27  INIFAP SALTILLO  2018-09-29 19:30:00   0.8  16.0
# 206   2767           27  INIFAP SALTILLO  2018-09-29 19:45:00   0.2  15.9
# 207   2768           27  INIFAP SALTILLO  2018-09-29 20:00:00   0.2  15.9
#
#       dirv  velv   radg  humr  humh  eto
# ...

# %%
del df2['index']

# %%
df2
# Out:
#      ID_estacion  Nombre_estacion                fecha  prec  temt   dirv  \
# 0             27  INIFAP SALTILLO  2018-09-01 20:00:00   0.2  17.9   83.8
# 1             27  INIFAP SALTILLO  2018-09-02 14:15:00   0.2  23.2  301.7
# 2             27  INIFAP SALTILLO  2018-09-02 14:30:00   3.4  21.5  116.8
# 3             27  INIFAP SALTILLO  2018-09-04 07:00:00   0.2  16.1  147.7
# 4             27  INIFAP SALTILLO  2018-09-04 15:45:00   1.0  21.0  311.0
# ..           ...              ...                  ...   ...   ...    ...
# 203           27  INIFAP SALTILLO  2018-09-29 19:00:00   0.4  16.4  207.0
# 204           27  INIFAP SALTILLO  2018-09-29 19:15:00   0.6  16.1  111.8
# 205           27  INIFAP SALTILLO  2018-09-29 19:30:00   0.8  16.0   23.5
# 206           27  INIFAP SALTILLO  2018-09-29 19:45:00   0.2  15.9  330.0
# 207           27  INIFAP SALTILLO  2018-09-29 20:00:00   0.2  15.9   39.4
#
#      velv   radg  humr  humh  eto
# 0    12.5    0.0  72.0   2.0  NaN
# ...

# %%
df = pd.read_csv(r'C:\Users\caroc\OneDrive\Documentos\datos_youtube\datos2.csv', encoding='latin1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_csv(r'C:\Users\caroc\OneDrive\Documentos\datos_youtube\datos2.csv', encoding='latin1')
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
df['category'].nunique() #buscamos las categorias
# Out:
# 18

# %%
lista = df['category'].unique()

# %%
lista         #filtramos las categorias y las ponemos en una lista
# Out:
# array(['Music', 'Film & Animation', 'Entertainment', 'Education', 'Shows',
#        nan, 'People & Blogs', 'Gaming', 'Sports', 'Howto & Style',
#        'News & Politics', 'Comedy', 'Trailers', 'Nonprofits & Activism',
#        'Science & Technology', 'Movies', 'Pets & Animals',
#        'Autos & Vehicles', 'Travel & Events'], dtype=object)

# %%
for categoria in lista:
    print(categoria)                             #separamos cada categoria y las guardamos en archivos diferentes 
    df2 = df[df.category == categoria]
    df2.to_csv('resultado_{}.csv'.format(categoria), index=False)
# Out:
# Music
# Film & Animation
# Entertainment
# Education
# Shows
# nan
# People & Blogs
# Gaming
# Sports
# Howto & Style
# News & Politics
# Comedy
# Trailers
# Nonprofits & Activism
# Science & Technology
# Movies
# Pets & Animals
# Autos & Vehicles
# Travel & Events

# %%
df['channel_type'].nunique()
# Out:
# 14

# %%
lista = df['channel_type'].unique()

# %%
lista
# Out:
# array(['Music', 'Games', 'Entertainment', 'Education', 'People', 'Sports',
#        'Film', 'News', nan, 'Comedy', 'Howto', 'Nonprofit', 'Autos',
#        'Tech', 'Animals'], dtype=object)

# %%
for canal in lista:
    print(canal)                            #antes creamos una carpeta desde el explorador de archivos que se llama "canales"
    df2 = df[df.channel_type == canal]      #y guardamos los canales (enlistados anteriormente) en la carpeta creada.
    df2.to_csv(r'C:\Users\caroc\Untitled Folder\Canales\resultado_{}.csv'.format(canal), index=False)
# Out:
# Music
# Games
# Entertainment
# Education
# People
# Sports
# Film
# News
# nan
# Comedy
# Howto
# Nonprofit
# Autos
# Tech
# Animals

# %%
df.head()
# Out:
#    ID_estacion  Nombre_estacion                fecha  prec  temt   dirv  velv  \
# 0           27  INIFAP SALTILLO  2018-09-01 00:00:00   0.0  18.8  154.4   1.0
# 1           27  INIFAP SALTILLO  2018-09-01 00:15:00   0.0  17.9   96.2   2.0
# 2           27  INIFAP SALTILLO  2018-09-01 00:30:00   NaN  17.4    NaN   2.3
# 3           27  INIFAP SALTILLO  2018-09-01 00:45:00   0.0  17.2  141.2   3.5
# 4           27  INIFAP SALTILLO  2018-09-01 01:00:00   0.0  16.5  130.0   3.8
#
#    radg  humr  humh  eto
# 0   0.0  71.0   2.0  NaN
# 1   0.0  77.0   2.0  NaN
# 2   NaN   NaN   NaN  NaN
# 3   0.0  79.0   2.0  0.0
# 4   0.0  82.0   2.0  NaN

# %%
df.info() #muestra los tipos de las colunmas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2880 entries, 0 to 2879
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID_estacion      2880 non-null   int64
#  1   Nombre_estacion  2880 non-null   object
#  2   fecha            2880 non-null   object
#  3   prec             2792 non-null   float64
#  4   temt             2880 non-null   float64
#  5   dirv             2842 non-null   float64
#  6   velv             2876 non-null   float64
#  7   radg             2854 non-null   float64
#  8   humr             2830 non-null   float64
#  9   humh             2802 non-null   float64
#  10  eto              720 non-null    float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 247.6+ KB

# %%
df['p_viento'] = df['dirv']*df['velv']

# %%
df
# Out:
#       ID_estacion  Nombre_estacion                fecha  prec  temt   dirv  \
# 0              27  INIFAP SALTILLO  2018-09-01 00:00:00   0.0  18.8  154.4
# 1              27  INIFAP SALTILLO  2018-09-01 00:15:00   0.0  17.9   96.2
# 2              27  INIFAP SALTILLO  2018-09-01 00:30:00   NaN  17.4    NaN
# 3              27  INIFAP SALTILLO  2018-09-01 00:45:00   0.0  17.2  141.2
# 4              27  INIFAP SALTILLO  2018-09-01 01:00:00   0.0  16.5  130.0
# ...           ...              ...                  ...   ...   ...    ...
# 2875           27  INIFAP SALTILLO  2018-09-30 22:45:00   0.0  14.2  102.5
# 2876           27  INIFAP SALTILLO  2018-09-30 23:00:00   0.0  14.4   43.0
# 2877           27  INIFAP SALTILLO  2018-09-30 23:15:00   0.0  15.0  108.8
# 2878           27  INIFAP SALTILLO  2018-09-30 23:30:00   0.0  15.3  177.6
# 2879           27  INIFAP SALTILLO  2018-09-30 23:45:00   0.0  15.2  187.7
#
#       velv  radg  humr  humh  eto  p_viento
# ...

# %%
df['p_viento']=0

# %%
df
# Out:
#       ID_estacion  Nombre_estacion                fecha  prec  temt   dirv  \
# 0              27  INIFAP SALTILLO  2018-09-01 00:00:00   0.0  18.8  154.4
# 1              27  INIFAP SALTILLO  2018-09-01 00:15:00   0.0  17.9   96.2
# 2              27  INIFAP SALTILLO  2018-09-01 00:30:00   NaN  17.4    NaN
# 3              27  INIFAP SALTILLO  2018-09-01 00:45:00   0.0  17.2  141.2
# 4              27  INIFAP SALTILLO  2018-09-01 01:00:00   0.0  16.5  130.0
# ...           ...              ...                  ...   ...   ...    ...
# 2875           27  INIFAP SALTILLO  2018-09-30 22:45:00   0.0  14.2  102.5
# 2876           27  INIFAP SALTILLO  2018-09-30 23:00:00   0.0  14.4   43.0
# 2877           27  INIFAP SALTILLO  2018-09-30 23:15:00   0.0  15.0  108.8
# 2878           27  INIFAP SALTILLO  2018-09-30 23:30:00   0.0  15.3  177.6
# 2879           27  INIFAP SALTILLO  2018-09-30 23:45:00   0.0  15.2  187.7
#
#       velv  radg  humr  humh  eto  p_viento
# ...

# %%
df['tormenta'] = 0
for index,rows in df.iterrows():
    if rows['prec'] >=2 and rows['velv']>=2:
        print('si')
        print('los datos {} y {}'.format(rows['prec'],rows['velv']))
        break
    else:
        print('no')
# Out:
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ...

# %%
df['tormenta']= 'no'

# %%
df
# Out:
#       ID_estacion  Nombre_estacion                fecha  prec  temt   dirv  \
# 0              27  INIFAP SALTILLO  2018-09-01 00:00:00   0.0  18.8  154.4
# 1              27  INIFAP SALTILLO  2018-09-01 00:15:00   0.0  17.9   96.2
# 2              27  INIFAP SALTILLO  2018-09-01 00:30:00   NaN  17.4    NaN
# 3              27  INIFAP SALTILLO  2018-09-01 00:45:00   0.0  17.2  141.2
# 4              27  INIFAP SALTILLO  2018-09-01 01:00:00   0.0  16.5  130.0
# ...           ...              ...                  ...   ...   ...    ...
# 2875           27  INIFAP SALTILLO  2018-09-30 22:45:00   0.0  14.2  102.5
# 2876           27  INIFAP SALTILLO  2018-09-30 23:00:00   0.0  14.4   43.0
# 2877           27  INIFAP SALTILLO  2018-09-30 23:15:00   0.0  15.0  108.8
# 2878           27  INIFAP SALTILLO  2018-09-30 23:30:00   0.0  15.3  177.6
# 2879           27  INIFAP SALTILLO  2018-09-30 23:45:00   0.0  15.2  187.7
#
#       velv  radg  humr  humh  eto  p_viento tormenta
# ...

# %%
df.loc[(df['prec']>=2)&(df['velv']>=2),'tormenta']='si'

# %%
df
# Out:
#       ID_estacion  Nombre_estacion                fecha  prec  temt   dirv  \
# 0              27  INIFAP SALTILLO  2018-09-01 00:00:00   0.0  18.8  154.4
# 1              27  INIFAP SALTILLO  2018-09-01 00:15:00   0.0  17.9   96.2
# 2              27  INIFAP SALTILLO  2018-09-01 00:30:00   NaN  17.4    NaN
# 3              27  INIFAP SALTILLO  2018-09-01 00:45:00   0.0  17.2  141.2
# 4              27  INIFAP SALTILLO  2018-09-01 01:00:00   0.0  16.5  130.0
# ...           ...              ...                  ...   ...   ...    ...
# 2875           27  INIFAP SALTILLO  2018-09-30 22:45:00   0.0  14.2  102.5
# 2876           27  INIFAP SALTILLO  2018-09-30 23:00:00   0.0  14.4   43.0
# 2877           27  INIFAP SALTILLO  2018-09-30 23:15:00   0.0  15.0  108.8
# 2878           27  INIFAP SALTILLO  2018-09-30 23:30:00   0.0  15.3  177.6
# 2879           27  INIFAP SALTILLO  2018-09-30 23:45:00   0.0  15.2  187.7
#
#       velv  radg  humr  humh  eto  p_viento tormenta
# ...

# %%
#queda pendiente comprarar los datos que estan nulos para poder ver los datos que tienen "si" en tormenta
#inv
# el df.iloc
